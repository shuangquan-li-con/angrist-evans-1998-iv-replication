# %% [markdown]
# <a href="https://colab.research.google.com/github/shuangquan-li-con/angrist-evans-1998-iv-replication/blob/main/Untitled48.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_path = "/AngEv98.zip"
extract_path = "AngEv98"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Unzipped files:")
print(os.listdir(extract_path))
# Out:
# Unzipped files:
# ['AngEv98']

# %%
import os

print(os.listdir("AngEv98/AngEv98"))
# Out:
# ['m_d_806.sas7bdat', 'm_d_903.sas7bdat']

# %%
import pandas as pd

df_1980 = pd.read_sas("AngEv98/AngEv98/m_d_806.sas7bdat")
df_1990 = pd.read_sas("AngEv98/AngEv98/m_d_903.sas7bdat")
# Out:
#    STATE  SEXK   AGEK QTRBKID  RACEK SPANISH BIRTHPLK SCHOOLK  GRADE FINGRADE  \
# 0  b'01'  b'1'  b'09'    b'3'  b'01'    b'0'   b'001'    b'1'  b'06'     b'1'
# 1  b'01'  b'1'  b'08'    b'3'  b'01'    b'0'   b'001'    b'2'  b'05'     b'1'
# 2  b'01'  b'0'  b'09'    b'1'  b'01'    b'0'   b'001'    b'1'  b'05'     b'1'
# 3  b'01'  b'0'  b'05'    b'2'  b'01'    b'0'   b'001'    b'1'  b'02'     b'1'
# 4  b'01'  b'1'  b'11'    b'1'  b'01'    b'0'   b'001'    b'1'  b'07'     b'1'
#
#    ... FINGRADD CLASSD WEEKSD HOURSD  INCOME1D  INCOME2D AWEEK79D  AHOUR79D  \
# 0  ...     b'2'   b'1'  b'52'  b'40'  b'28005'  b'00000'     b'0'      b'0'
# 1  ...     b'2'   b'5'  b'52'  b'72'  b'00000'  b'10005'     b'0'      b'0'
# 2  ...     b'2'   b'5'  b'16'  b'48'  b'00000'  b'16005'     b'0'      b'0'
# 3  ...      NaN    NaN    NaN    NaN       NaN       NaN      NaN       NaN
# 4  ...     b'2'   b'1'  b'32'  b'40'  b'09925'  b'00000'     b'0'      b'0'
#
#    AINC1D AINC2D
# 0    b'0'   b'0'
# ...

# %%
print(df_1980.head())
print(df_1990.head())
# Out:
#    STATE  SEXK   AGEK QTRBKID  RACEK SPANISH BIRTHPLK SCHOOLK  GRADE FINGRADE  \
# 0  b'01'  b'1'  b'09'    b'3'  b'01'    b'0'   b'001'    b'1'  b'06'     b'1'
# 1  b'01'  b'1'  b'08'    b'3'  b'01'    b'0'   b'001'    b'2'  b'05'     b'1'
# 2  b'01'  b'0'  b'09'    b'1'  b'01'    b'0'   b'001'    b'1'  b'05'     b'1'
# 3  b'01'  b'0'  b'05'    b'2'  b'01'    b'0'   b'001'    b'1'  b'02'     b'1'
# 4  b'01'  b'1'  b'11'    b'1'  b'01'    b'0'   b'001'    b'1'  b'07'     b'1'
#
#    ... FINGRADD CLASSD WEEKSD HOURSD  INCOME1D  INCOME2D AWEEK79D  AHOUR79D  \
# 0  ...     b'2'   b'1'  b'52'  b'40'  b'28005'  b'00000'     b'0'      b'0'
# 1  ...     b'2'   b'5'  b'52'  b'72'  b'00000'  b'10005'     b'0'      b'0'
# 2  ...     b'2'   b'5'  b'16'  b'48'  b'00000'  b'16005'     b'0'      b'0'
# 3  ...      NaN    NaN    NaN    NaN       NaN       NaN      NaN       NaN
# 4  ...     b'2'   b'1'  b'32'  b'40'  b'09925'  b'00000'     b'0'      b'0'
#
#    AINC1D AINC2D
# 0    b'0'   b'0'
# ...
